# %%
from pennylane import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import sys
sys.path.insert(0, '/Users/tak/Github/QEmbedding/')
import Hybrid_nn
import torch
from torch import nn
import data
import pennylane as qml
import embedding

# %% [markdown]
# # Trace distance History (Embedding Training)

# %%
PATHs_Model2, PATHs_Model3 = [], []

for i in range(49):
    PATH_Model2 = f'/Users/tak/Github/QEmbedding/Results/QCNN_demonstration/Real device/Real/Model2 pre-train/Model2_{i}.pt'
    PATH_Model3 = f'/Users/tak/Github/QEmbedding/Results/QCNN_demonstration/Real device/Real/Model3 pre-train/Model3_{i}.pt'

    PATHs_Model2.append(PATH_Model2)
    PATHs_Model3.append(PATH_Model3)

# %%
dev_sim = qml.device('default.qubit', wires=4)
@qml.qnode(dev_sim, interface="torch")
def Noisy_Distance(inputs): 
    embedding.Noisy_Four_QuantumEmbedding2(inputs)
    return qml.density_matrix(wires=range(4))

class Distances2(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.qlayer2 = qml.qnn.TorchLayer(Noisy_Distance, weight_shapes={})
        self.linear_relu_stack2 = nn.Sequential(
            nn.Linear(4, 12),
            nn.ReLU(),
            nn.Linear(12, 12),
            nn.ReLU(),
            nn.Linear(12, 7)
        )
    def forward(self, x1, x0):
        x1 = self.linear_relu_stack2(x1)
        x0 = self.linear_relu_stack2(x0)
        rhos1 = self.qlayer2(x1)
        rhos0 = self.qlayer2(x0)

        rho1 = torch.sum(rhos1, dim=0) / len(x1)
        rho0 = torch.sum(rhos0, dim=0) / len(x0)
        rho_diff = rho1 - rho0
        eigvals = torch.linalg.eigvals(rho_diff)
        return 0.5 * torch.real(torch.sum(torch.abs(eigvals)))


class Distances3(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.qlayer3 = qml.qnn.TorchLayer(Noisy_Distance, weight_shapes={})
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(1, 1, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Layer2: 14 * 14 -> 7 * 7
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(1, 1, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Fully connected Layers 7 * 7 -> 7
        self.fc = torch.nn.Linear(7 * 7, 7, bias=True)
    
    def forward(self, x1, x0):
        x1 = self.layer1(x1)
        x1 = self.layer2(x1)
        x1 = x1.view(-1, 7 * 7)
        x1 = self.fc(x1)

        x0 = self.layer1(x0)
        x0 = self.layer2(x0)
        x0 = x0.view(-1, 7 * 7)
        x0 = self.fc(x0)

        rhos1 = self.qlayer3(x1)
        rhos0 = self.qlayer3(x0)
        
        rho1 = torch.sum(rhos1, dim=0) / len(x1)
        rho0 = torch.sum(rhos0, dim=0) / len(x0)
        rho_diff = rho1 - rho0
        eigvals = torch.linalg.eigvals(rho_diff)
        return 0.5 * torch.real(torch.sum(torch.abs(eigvals)))

# Calculated from Model1 
Trace_before_traindata = 0.2734867334365845
Trace_before_testdata = 0.2723434865474701

# %%
def D(PATH, Model, X1, X0):
    if Model == 'Model2':
        Distance = Distances2()
    elif Model == 'Model3':
        Distance = Distances3()
    
    Distance.load_state_dict(torch.load(PATH))
    return Distance(X1, X0)

# %% [markdown]
# Model 2

# %%
feature_reduction = 'PCA4'
classes = [0,1]
X_train, X_test, Y_train, Y_test = data.data_load_and_process('mnist', feature_reduction=feature_reduction, classes=classes)

X1_test, X0_test = [], []
for i in range(len(X_test)):
    if Y_test[i] == 1:
        X1_test.append(X_test[i])
    else:
        X0_test.append(X_test[i])
X1_test, X0_test = torch.tensor(X1_test).to(torch.float32), torch.tensor(X0_test).to(torch.float32)

X1_train, X0_train = [], []
for i in range(len(X_train)):
    if Y_train[i] == 1:
        X1_train.append(X_train[i])
    else:
        X0_train.append(X_train[i])
X1_train, X0_train = torch.tensor(X1_train).to(torch.float32), torch.tensor(X0_train).to(torch.float32)
# Out:
# /var/folders/ym/ry24dhs911s7zbqfbhs5ns2m0000gn/T/ipykernel_11547/3063670933.py:11: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1670525498485/work/torch/csrc/utils/tensor_new.cpp:233.)
#   X1_test, X0_test = torch.tensor(X1_test).to(torch.float32), torch.tensor(X0_test).to(torch.float32)

# %%
Trace_Distance_history_Model2_Train = [D(PATH=p, Model='Model2', X1=X1_train, X0=X0_train).detach().numpy() for p in PATHs_Model2]
Trace_Distance_history_Model2_Test = [D(PATH=p, Model='Model2', X1=X1_test, X0=X0_test).detach().numpy() for p in PATHs_Model2]
# Out:
# /Users/tak/miniforge3/envs/QC/lib/python3.10/site-packages/pennylane/qnn/torch.py:328: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1670525498485/work/aten/src/ATen/native/Copy.cpp:250.)
#   return self.qnode(**kwargs).type(x.dtype)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Model2 Trace Distance History')
plt.rcParams['figure.figsize'] = [2, 10]
ax1.scatter(range(49), Trace_Distance_history_Model2_Train)
ax2.scatter(range(49), Trace_Distance_history_Model2_Test)
ax1.set_xlabel('iterations')
ax2.set_xlabel('iterations')
ax1.set_ylabel('Trace Distance')
ax2.set_ylabel('Trace Distance')
ax1.set_title('Train data')
ax2.set_title('Test data')
plt.show()

# %% [markdown]
# Model 3

# %%
feature_reduction = False
classes = [0,1]
X_train, X_test, Y_train, Y_test = data.data_load_and_process('mnist', feature_reduction=feature_reduction, classes=classes)

X1_test, X0_test = [], []
for i in range(len(X_test)):
    if Y_test[i] == 1:
        X1_test.append(X_test[i])
    else:
        X0_test.append(X_test[i])
X1_test, X0_test = torch.tensor(X1_test).to(torch.float32), torch.tensor(X0_test).to(torch.float32)
X1_test, X0_test = X1_test.permute(0, 3, 1, 2), X0_test.permute(0, 3, 1, 2)

X1_train, X0_train = [], []
for i in range(len(X_train)):
    if Y_train[i] == 1:
        X1_train.append(X_train[i])
    else:
        X0_train.append(X_train[i])
X1_train, X0_train = torch.tensor(X1_train).to(torch.float32), torch.tensor(X0_train).to(torch.float32)
X1_train, X0_train = X1_train.permute(0, 3, 1, 2), X0_train.permute(0, 3, 1, 2)

# %%
Trace_Distance_history_Model3_Train = [D(PATH=p, Model='Model3', X1=X1_train, X0=X0_train).detach().numpy() for p in PATHs_Model3]
Trace_Distance_history_Model3_Test = [D(PATH=p, Model='Model3', X1=X1_test, X0=X0_test).detach().numpy() for p in PATHs_Model3]

# %%
fig2, (ax1, ax2) = plt.subplots(1, 2)
plt.rcParams['figure.figsize'] = [2, 10]
fig2.suptitle('Model3 Trace Distance History')
ax1.scatter(range(49), Trace_Distance_history_Model3_Train)
ax2.scatter(range(49), Trace_Distance_history_Model3_Test)
ax1.set_xlabel('iterations')
ax2.set_xlabel('iterations')
ax1.set_ylabel('Trace Distance')
ax2.set_ylabel('Trace Distance')
ax1.set_title('Train data')
ax2.set_title('Test data')
plt.show()

# %%
Trace_Distance_history_Model2_Test
# Out:
# [array(0.23754369, dtype=float32),
#  array(0.2805084, dtype=float32),
#  array(0.36385763, dtype=float32),
#  array(0.51256853, dtype=float32),
#  array(0.6111796, dtype=float32),
#  array(0.70102996, dtype=float32),
#  array(0.7706995, dtype=float32),
#  array(0.790357, dtype=float32),
#  array(0.7997946, dtype=float32),
#  array(0.82678866, dtype=float32),
#  array(0.827813, dtype=float32),
#  array(0.8383052, dtype=float32),
#  array(0.83582705, dtype=float32),
#  array(0.85325086, dtype=float32),
#  array(0.84059954, dtype=float32),
#  array(0.83368284, dtype=float32),
#  array(0.84546006, dtype=float32),
#  array(0.85999566, dtype=float32),
#  array(0.8511368, dtype=float32),
#  array(0.85475814, dtype=float32),
#  array(0.8420975, dtype=float32),
#  array(0.83949316, dtype=float32),
#  array(0.8329082, dtype=float32),
#  array(0.84480274, dtype=float32),
#  array(0.852304, dtype=float32),
#  array(0.85709774, dtype=float32),
#  array(0.8423266, dtype=float32),
#  array(0.8518667, dtype=float32),
#  array(0.86907506, dtype=float32),
#  array(0.87251484, dtype=float32),
#  array(0.88021207, dtype=float32),
#  array(0.8793357, dtype=float32),
#  array(0.8784944, dtype=float32),
#  array(0.87817967, dtype=float32),
#  array(0.86044925, dtype=float32),
#  array(0.86238587, dtype=float32),
#  array(0.85107744, dtype=float32),
#  array(0.8562262, dtype=float32),
#  array(0.86158395, dtype=float32),
#  array(0.863262, dtype=float32),
#  array(0.8685412, dtype=float32),
#  array(0.8653492, dtype=float32),
#  array(0.85471547, dtype=float32),
#  array(0.8371555, dtype=float32),
#  array(0.8491075, dtype=float32),
#  array(0.85157114, dtype=float32),
#  array(0.8585215, dtype=float32),
#  array(0.84274936, dtype=float32),
#  array(0.85201687, dtype=float32)]

# %%
Trace_Distance_history_Model2_Train
# Out:
# [array(0.22594407, dtype=float32),
#  array(0.26793045, dtype=float32),
#  array(0.34953657, dtype=float32),
#  array(0.49141434, dtype=float32),
#  array(0.58578604, dtype=float32),
#  array(0.67346764, dtype=float32),
#  array(0.74317586, dtype=float32),
#  array(0.76373786, dtype=float32),
#  array(0.77368504, dtype=float32),
#  array(0.80234814, dtype=float32),
#  array(0.8044468, dtype=float32),
#  array(0.81565046, dtype=float32),
#  array(0.8149117, dtype=float32),
#  array(0.83347106, dtype=float32),
#  array(0.8209968, dtype=float32),
#  array(0.8151336, dtype=float32),
#  array(0.82701254, dtype=float32),
#  array(0.8428513, dtype=float32),
#  array(0.83477575, dtype=float32),
#  array(0.8388988, dtype=float32),
#  array(0.82566273, dtype=float32),
#  array(0.8233313, dtype=float32),
#  array(0.8172971, dtype=float32),
#  array(0.82931185, dtype=float32),
#  array(0.83666414, dtype=float32),
#  array(0.84172755, dtype=float32),
#  array(0.8279606, dtype=float32),
#  array(0.83813775, dtype=float32),
#  array(0.855282, dtype=float32),
#  array(0.8586858, dtype=float32),
#  array(0.86646366, dtype=float32),
#  array(0.86593974, dtype=float32),
#  array(0.865129, dtype=float32),
#  array(0.86486334, dtype=float32),
#  array(0.84760123, dtype=float32),
#  array(0.8495521, dtype=float32),
#  array(0.83862484, dtype=float32),
#  array(0.8440941, dtype=float32),
#  array(0.849602, dtype=float32),
#  array(0.85133713, dtype=float32),
#  array(0.85669357, dtype=float32),
#  array(0.85310364, dtype=float32),
#  array(0.84317404, dtype=float32),
#  array(0.82623875, dtype=float32),
#  array(0.8379359, dtype=float32),
#  array(0.84038985, dtype=float32),
#  array(0.8471444, dtype=float32),
#  array(0.8309541, dtype=float32),
#  array(0.8402629, dtype=float32)]

# %%
Trace_Distance_history_Model3_Test
# Out:
# [array(0.06475333, dtype=float32),
#  array(0.06918226, dtype=float32),
#  array(0.07647946, dtype=float32),
#  array(0.07627889, dtype=float32),
#  array(0.07980315, dtype=float32),
#  array(0.09406134, dtype=float32),
#  array(0.10748157, dtype=float32),
#  array(0.11553331, dtype=float32),
#  array(0.11959384, dtype=float32),
#  array(0.11910678, dtype=float32),
#  array(0.12796526, dtype=float32),
#  array(0.14699663, dtype=float32),
#  array(0.16462788, dtype=float32),
#  array(0.18235089, dtype=float32),
#  array(0.2555993, dtype=float32),
#  array(0.25508493, dtype=float32),
#  array(0.28756076, dtype=float32),
#  array(0.35579115, dtype=float32),
#  array(0.44905427, dtype=float32),
#  array(0.50318706, dtype=float32),
#  array(0.5145913, dtype=float32),
#  array(0.6048323, dtype=float32),
#  array(0.59627396, dtype=float32),
#  array(0.68582016, dtype=float32),
#  array(0.7138007, dtype=float32),
#  array(0.7328345, dtype=float32),
#  array(0.72549075, dtype=float32),
#  array(0.6741883, dtype=float32),
#  array(0.70906466, dtype=float32),
#  array(0.78430295, dtype=float32),
#  array(0.73629844, dtype=float32),
#  array(0.7764811, dtype=float32),
#  array(0.75536484, dtype=float32),
#  array(0.7442108, dtype=float32),
#  array(0.7930176, dtype=float32),
#  array(0.82411444, dtype=float32),
#  array(0.8437658, dtype=float32),
#  array(0.8617225, dtype=float32),
#  array(0.812293, dtype=float32),
#  array(0.8181512, dtype=float32),
#  array(0.81995106, dtype=float32),
#  array(0.8074144, dtype=float32),
#  array(0.7422178, dtype=float32),
#  array(0.76565915, dtype=float32),
#  array(0.79594326, dtype=float32),
#  array(0.8353813, dtype=float32),
#  array(0.799433, dtype=float32),
#  array(0.7898419, dtype=float32),
#  array(0.793808, dtype=float32)]

# %%
Trace_Distance_history_Model3_Train
# Out:
# [array(0.06521993, dtype=float32),
#  array(0.06970417, dtype=float32),
#  array(0.07709334, dtype=float32),
#  array(0.07684017, dtype=float32),
#  array(0.08037274, dtype=float32),
#  array(0.09476833, dtype=float32),
#  array(0.10833697, dtype=float32),
#  array(0.11640207, dtype=float32),
#  array(0.12042605, dtype=float32),
#  array(0.11981178, dtype=float32),
#  array(0.12871543, dtype=float32),
#  array(0.14784448, dtype=float32),
#  array(0.16562541, dtype=float32),
#  array(0.18342842, dtype=float32),
#  array(0.2568775, dtype=float32),
#  array(0.25623122, dtype=float32),
#  array(0.28880972, dtype=float32),
#  array(0.35698542, dtype=float32),
#  array(0.45012683, dtype=float32),
#  array(0.50364655, dtype=float32),
#  array(0.5150446, dtype=float32),
#  array(0.6037009, dtype=float32),
#  array(0.5950746, dtype=float32),
#  array(0.6840983, dtype=float32),
#  array(0.7119718, dtype=float32),
#  array(0.73076487, dtype=float32),
#  array(0.7231304, dtype=float32),
#  array(0.67165273, dtype=float32),
#  array(0.7071878, dtype=float32),
#  array(0.7828505, dtype=float32),
#  array(0.7349852, dtype=float32),
#  array(0.7755175, dtype=float32),
#  array(0.7544305, dtype=float32),
#  array(0.74305713, dtype=float32),
#  array(0.7921089, dtype=float32),
#  array(0.8229555, dtype=float32),
#  array(0.8419412, dtype=float32),
#  array(0.8594442, dtype=float32),
#  array(0.8098141, dtype=float32),
#  array(0.8155871, dtype=float32),
#  array(0.81788903, dtype=float32),
#  array(0.80478966, dtype=float32),
#  array(0.73977715, dtype=float32),
#  array(0.763343, dtype=float32),
#  array(0.79346615, dtype=float32),
#  array(0.83226246, dtype=float32),
#  array(0.79677165, dtype=float32),
#  array(0.78791875, dtype=float32),
#  array(0.79202795, dtype=float32)]

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig, (ax1, ax2) = plt.subplots(1,2)
clrs = sns.color_palette("husl", 3)
with sns.axes_style("darkgrid"):
    ax1.scatter(range(49), Trace_Distance_history_Model2_Train, label="Model2", c=clrs[0])
    ax1.scatter(range(49), Trace_Distance_history_Model3_Train, label="Model3", c=clrs[1])
    ax1.plot(range(49), np.ones(49) * Trace_before_traindata, linestyle='dashed', linewidth=1.5, label="No pre-training", c=clrs[2])
    
    ax2.scatter(range(49), Trace_Distance_history_Model2_Test, label="Model2", c=clrs[0])
    ax2.scatter(range(49), Trace_Distance_history_Model3_Test, label="Model3", c=clrs[1])
    ax2.plot(range(49), np.ones(49) * Trace_before_testdata, linestyle='dashed', linewidth=1.5, label="No pre-training", c=clrs[2])

ax1.set_xlabel("Iteration")
ax1.set_ylabel("Trace Distance")
ax1.set_title("Training data")
ax1.legend()

ax2.set_xlabel("Iteration")
ax2.set_ylabel("Trace Distance")
ax2.set_title("Test data")
ax2.legend()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
f = open("/Users/tak/Github/QEmbedding/Results/QCNN_demonstration/Real device/Real/Trace Distance History.txt", "w")
f.write("Trace Distance History Model2 Train: \n")
f.write(str(Trace_Distance_history_Model2_Train))
f.write("\n")
f.write("Trace Distance History Model2 Test: \n")
f.write(str(Trace_Distance_history_Model2_Test))
f.write("\n")
f.write("Trace Distance History Model3 Train: \n")
f.write(str(Trace_Distance_history_Model3_Train))
f.write("\n")
f.write("Trace Distance History Model3 Test: \n")
f.write(str(Trace_Distance_history_Model3_Test))
f.write("\n")
f.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import genfromtxt
import itertools

# %% [markdown]
# ## 1. Plot Training Loss History

# %%
Model3_Fidelity, Model3_HSinner = [], []

for i in range(5):
    Model3_Fidelity_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 Fidelity/Training_Loss_History.txt'
    Model3_HSinner_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 HSinner/Training_Loss_History.txt'

    Model3_Fidelity.append(genfromtxt(Model3_Fidelity_PATH, delimiter=',').tolist())
    Model3_HSinner.append(genfromtxt(Model3_HSinner_PATH, delimiter=',').tolist())


Model3_Fidelity = list(itertools.zip_longest(*Model3_Fidelity, fillvalue=np.nan))
Model3_HSinner = list(itertools.zip_longest(*Model3_HSinner, fillvalue=np.nan))

Model3_Fidelity_mean = np.array([np.nanmean(i) for i in Model3_Fidelity])
Model3_Fidelity_std = np.array([np.nanstd(i) for i in Model3_Fidelity])

Model3_HSinner_mean = np.array([np.nanmean(i) for i in Model3_HSinner])
Model3_HSinner_std = np.array([np.nanstd(i) for i in Model3_HSinner])

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(range(len(Model3_Fidelity_mean)), Model3_Fidelity_mean, label="Model3_Fidelity", c=clrs[0])
    ax.fill_between(range(len(Model3_Fidelity_mean)), Model3_Fidelity_mean-Model3_Fidelity_std, Model3_Fidelity_mean+Model3_Fidelity_std, alpha=0.3,facecolor=clrs[0])

    ax.plot(range(len(Model3_HSinner_mean)), Model3_HSinner_mean, label="Model3_HSinner", c=clrs[1])
    ax.fill_between(range(len(Model3_HSinner_mean)), Model3_HSinner_mean-Model3_HSinner_std, Model3_HSinner_mean+Model3_HSinner_std, alpha=0.3,facecolor=clrs[1])

ax.set_title("Model3 Training Loss History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 2. Plot Validation Loss History

# %%
Model3_Fidelity, Model3_HSinner = [], []

for i in range(5):
    Model3_Fidelity_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 Fidelity/Validation_Loss_History.txt'
    Model3_HSinner_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 HSinner/Validation_Loss_History.txt'

    Model3_Fidelity.append(genfromtxt(Model3_Fidelity_PATH, delimiter=',').tolist())
    Model3_HSinner.append(genfromtxt(Model3_HSinner_PATH, delimiter=',').tolist())

Model3_Fidelity = list(itertools.zip_longest(*Model3_Fidelity, fillvalue=np.nan))
Model3_HSinner = list(itertools.zip_longest(*Model3_HSinner, fillvalue=np.nan))

Model3_Fidelity_mean = np.array([np.nanmean(i) for i in Model3_Fidelity])
Model3_Fidelity_std = np.array([np.nanstd(i) for i in Model3_Fidelity])

Model3_HSinner_mean = np.array([np.nanmean(i) for i in Model3_HSinner])
Model3_HSinner_std = np.array([np.nanstd(i) for i in Model3_HSinner])

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean, label="Model3_Fidelity", c=clrs[0])
    ax.fill_between(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean-Model3_Fidelity_std, Model3_Fidelity_mean+Model3_Fidelity_std, alpha=0.3,facecolor=clrs[0])

    ax.plot(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean, label="Model3_HSinner", c=clrs[1])
    ax.fill_between(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean-Model3_HSinner_std, Model3_HSinner_mean+Model3_HSinner_std, alpha=0.3,facecolor=clrs[1])

ax.set_title("Model3 Validation Loss History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 3. Plot Validation Accuracy 0.9 Threshold

# %%
Model3_Fidelity, Model3_HSinner = [], []

for i in range(5):
    Model3_Fidelity_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 Fidelity/Validation_Accuracy90_History.txt'
    Model3_HSinner_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 HSinner/Validation_Accuracy90_History.txt'

    Model3_Fidelity.append(genfromtxt(Model3_Fidelity_PATH, delimiter=',').tolist())
    Model3_HSinner.append(genfromtxt(Model3_HSinner_PATH, delimiter=',').tolist())

Model3_Fidelity = list(itertools.zip_longest(*Model3_Fidelity, fillvalue=np.nan))
Model3_HSinner = list(itertools.zip_longest(*Model3_HSinner, fillvalue=np.nan))

Model3_Fidelity_mean = np.array([np.nanmean(i) for i in Model3_Fidelity])
Model3_Fidelity_std = np.array([np.nanstd(i) for i in Model3_Fidelity])

Model3_HSinner_mean = np.array([np.nanmean(i) for i in Model3_HSinner])
Model3_HSinner_std = np.array([np.nanstd(i) for i in Model3_HSinner])

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean, label="Model3_Fidelity", c=clrs[0])
    ax.fill_between(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean-Model3_Fidelity_std, Model3_Fidelity_mean+Model3_Fidelity_std, alpha=0.3,facecolor=clrs[0])

    ax.plot(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean, label="Model3_HSinner", c=clrs[1])
    ax.fill_between(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean-Model3_HSinner_std, Model3_HSinner_mean+Model3_HSinner_std, alpha=0.3,facecolor=clrs[1])

ax.set_title("Model3 Validation Accuracy90 Loss History").set_fontsize(15)
ax.set_ylabel("Accuracy").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 4. Plot Validation Accuracy 0.8 Threshold

# %%
Model3_Fidelity, Model3_HSinner = [], []

for i in range(5):
    Model3_Fidelity_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 Fidelity/Validation_Accuracy80_History.txt'
    Model3_HSinner_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model3 HSinner/Validation_Accuracy80_History.txt'

    Model3_Fidelity.append(genfromtxt(Model3_Fidelity_PATH, delimiter=',').tolist())
    Model3_HSinner.append(genfromtxt(Model3_HSinner_PATH, delimiter=',').tolist())

Model3_Fidelity = list(itertools.zip_longest(*Model3_Fidelity, fillvalue=np.nan))
Model3_HSinner = list(itertools.zip_longest(*Model3_HSinner, fillvalue=np.nan))

Model3_Fidelity_mean = np.array([np.nanmean(i) for i in Model3_Fidelity])
Model3_Fidelity_std = np.array([np.nanstd(i) for i in Model3_Fidelity])

Model3_HSinner_mean = np.array([np.nanmean(i) for i in Model3_HSinner])
Model3_HSinner_std = np.array([np.nanstd(i) for i in Model3_HSinner])

# %%
plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean, label="Model3_Fidelity", c=clrs[0])
    ax.fill_between(np.array(range(len(Model3_Fidelity_mean))) * 10, Model3_Fidelity_mean-Model3_Fidelity_std, Model3_Fidelity_mean+Model3_Fidelity_std, alpha=0.3,facecolor=clrs[0])

    ax.plot(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean, label="Model3_HSinner", c=clrs[1])
    ax.fill_between(np.array(range(len(Model3_HSinner_mean))) * 10, Model3_HSinner_mean-Model3_HSinner_std, Model3_HSinner_mean+Model3_HSinner_std, alpha=0.3,facecolor=clrs[1])

ax.set_title("Model3 Validation Accuracy80 Loss History").set_fontsize(15)
ax.set_ylabel("Accuracy").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## Test Results

# %%
Model3_Fidelity_Test_Loss = np.array([0.01460453774780035, 0.015565389767289162, 0.017129451036453247, 0.01813260093331337, 0.015324593521654606])
Model3_Fidelity_Test_Accuracy90 = np.array([74.26, 71.61999999999999, 70.08, 69.75, 70.52000000000001])
Model3_Fidelity_Test_Accruacy80 = np.array([92.09, 90.53999999999999, 89.03, 89.91, 90.41])

Model3_HSinner_Test_Loss = np.array([0.020147232338786125, 0.014450538903474808, 0.018341142684221268, 0.016973568126559258, 0.014610376209020615])
Model3_HSinner_Test_Accuracy90 = np.array([68.92, 72.82, 69.1, 69.89999999999999, 72.81])
Model3_HSinner_Test_Accruacy80 = np.array([87.4, 91.36999999999999, 90.28, 89.14999999999999, 91.39])


Model3_Fidelity_Test_Loss_mean, Model3_Fidelity_Test_Loss_std = Model3_Fidelity_Test_Loss.mean(), Model3_Fidelity_Test_Loss.std()
Model3_Fidelity_Test_Accuracy90_mean, Model3_Fidelity_Test_Accuracy90_std = Model3_Fidelity_Test_Accuracy90.mean(), Model3_Fidelity_Test_Accuracy90.std()
Model3_Fidelity_Test_Accuracy80_mean, Model3_Fidelity_Test_Accuracy80_std = Model3_Fidelity_Test_Accruacy80.mean(), Model3_Fidelity_Test_Accruacy80.std()

Model3_HSinner_Test_Loss_mean, Model3_HSinner_Test_Loss_std = Model3_HSinner_Test_Loss.mean(), Model3_HSinner_Test_Loss.std()
Model3_HSinner_Test_Accuracy90_mean, Model3_HSinner_Test_Accuracy90_std = Model3_HSinner_Test_Accuracy90.mean(), Model3_HSinner_Test_Accuracy90.std()
Model3_HSinner_Test_Accuracy80_mean, Model3_HSinner_Test_Accuracy80_std = Model3_HSinner_Test_Accruacy80.mean(), Model3_HSinner_Test_Accruacy80.std()

print("Model3 with Fidelity")
print("------------------------")
print(f"Test Loss: {Model3_Fidelity_Test_Loss_mean} ± {Model3_Fidelity_Test_Loss_std}")
print(f"Test Accuracy90: {Model3_Fidelity_Test_Accuracy90_mean} ± {Model3_Fidelity_Test_Accuracy90_std}")
print(f"Test Accuracy80: {Model3_Fidelity_Test_Accuracy80_mean} ± {Model3_Fidelity_Test_Accuracy80_std}\n")

print("Model3 with HSinner")
print("------------------------")
print(f"Test Loss: {Model3_HSinner_Test_Loss_mean} ± {Model3_HSinner_Test_Loss_std}")
print(f"Test Accuracy90: {Model3_HSinner_Test_Accuracy90_mean} ± {Model3_HSinner_Test_Accuracy90_std}")
print(f"Test Accuracy80: {Model3_HSinner_Test_Accuracy80_mean} ± {Model3_HSinner_Test_Accuracy80_std}\n")
# Out:
# Model3 with Fidelity
# ------------------------
# Test Loss: 0.016151314601302147 ± 0.0012885294489735379
# Test Accuracy90: 71.24600000000001 ± 1.6339351272311893
# Test Accuracy80: 90.39599999999999 ± 0.999271734814911
#
# Model3 with HSinner
# ------------------------
# Test Loss: 0.016904571652412416 ± 0.0021849006675438883
# Test Accuracy90: 70.71000000000001 ± 1.7501085680608506
# Test Accuracy80: 89.91799999999998 ± 1.5057410135876594

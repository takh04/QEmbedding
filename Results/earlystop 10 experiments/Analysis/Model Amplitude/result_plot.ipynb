# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import genfromtxt
import itertools

# %% [markdown]
# ## 1. Plot Training Loss History

# %%
Model_Amplitude = []

for i in range(5):
    Model_Amplitude_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model Amplitude/Training_Loss_History.txt'
    Model_Amplitude.append(genfromtxt(Model_Amplitude_PATH, delimiter=',').tolist())

Model_Amplitude = list(itertools.zip_longest(*Model_Amplitude, fillvalue=np.nan))
Model_Amplitude_mean = np.array([np.nanmean(i) for i in Model_Amplitude])
Model_Amplitude_std = np.array([np.nanstd(i) for i in Model_Amplitude])


plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(range(len(Model_Amplitude_mean)), Model_Amplitude_mean, label="Model_Amplitude", c=clrs[0])
    ax.fill_between(range(len(Model_Amplitude_mean)), Model_Amplitude_mean-Model_Amplitude_std, Model_Amplitude_mean+Model_Amplitude_std, alpha=0.3,facecolor=clrs[0])

ax.set_title("Model Amplitude Training Loss History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 2. Plot Validation Loss History

# %%
Model_Amplitude = []

for i in range(5):
    Model_Amplitude_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model Amplitude/Validation_Loss_History.txt'
    Model_Amplitude.append(genfromtxt(Model_Amplitude_PATH, delimiter=',').tolist())

Model_Amplitude = list(itertools.zip_longest(*Model_Amplitude, fillvalue=np.nan))
Model_Amplitude_mean = np.array([np.nanmean(i) for i in Model_Amplitude])
Model_Amplitude_std = np.array([np.nanstd(i) for i in Model_Amplitude])


plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean, label="Model_Amplitude", c=clrs[0])
    ax.fill_between(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean-Model_Amplitude_std, Model_Amplitude_mean+Model_Amplitude_std, alpha=0.3,facecolor=clrs[0])

ax.set_title("Model Amplitude Validation Loss History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 3. Plot Validation Accuracy 0.9 Threshold

# %%
Model_Amplitude = []

for i in range(5):
    Model_Amplitude_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model Amplitude/Validation_Accuracy90_History.txt'
    Model_Amplitude.append(genfromtxt(Model_Amplitude_PATH, delimiter=',').tolist())

Model_Amplitude = list(itertools.zip_longest(*Model_Amplitude, fillvalue=np.nan))
Model_Amplitude_mean = np.array([np.nanmean(i) for i in Model_Amplitude])
Model_Amplitude_std = np.array([np.nanstd(i) for i in Model_Amplitude])


plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean, label="Model_Amplitude", c=clrs[0])
    ax.fill_between(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean-Model_Amplitude_std, Model_Amplitude_mean+Model_Amplitude_std, alpha=0.3,facecolor=clrs[0])

ax.set_title("Model Amplitude Validation Accuracy90 History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## 4. Plot Validation Accuracy 0.8 Threshold

# %%
Model_Amplitude = []

for i in range(5):
    Model_Amplitude_PATH = f'/Users/tak/Github/QEmbedding/Results/earlystop 10 experiments/experiment{i+1}/Model Amplitude/Validation_Accuracy80_History.txt'
    Model_Amplitude.append(genfromtxt(Model_Amplitude_PATH, delimiter=',').tolist())

Model_Amplitude = list(itertools.zip_longest(*Model_Amplitude, fillvalue=np.nan))
Model_Amplitude_mean = np.array([np.nanmean(i) for i in Model_Amplitude])
Model_Amplitude_std = np.array([np.nanstd(i) for i in Model_Amplitude])


plt.rcParams['figure.figsize'] = [10, 5]
fig, ax = plt.subplots()
clrs = sns.color_palette("husl", 4)
with sns.axes_style("darkgrid"):
    ax.plot(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean, label="Model_Amplitude", c=clrs[0])
    ax.fill_between(np.arange(len(Model_Amplitude_mean)) * 10, Model_Amplitude_mean-Model_Amplitude_std, Model_Amplitude_mean+Model_Amplitude_std, alpha=0.3,facecolor=clrs[0])

ax.set_title("Model Amplitude Validation Accuracy90 History").set_fontsize(15)
ax.set_ylabel("Loss").set_fontsize(15)
ax.set_xlabel("Iterations").set_fontsize(15)
ax.legend()

# %% [markdown]
# ## Test Results

# %%
Model_Amplitude_Test_Loss = np.array([0.030571117997169495, 0.029605181887745857, 0.03087393194437027, 0.03004375472664833, 0.03018542379140854])
Model_Amplitude_Test_Accuracy90 = np.array([71.34, 67.9, 65.33, 65.9, 64.41])
Model_Amplitude_Test_Accruacy80 = np.array([87.28, 88.09, 86.02, 86.25, 85.22])

Model_Amplitude_Test_Loss_mean, Model_Amplitude_Test_Loss_std = Model_Amplitude_Test_Loss.mean(), Model_Amplitude_Test_Loss.std()
Model_Amplitude_Test_Accuracy90_mean, Model_Amplitude_Test_Accuracy90_std = Model_Amplitude_Test_Accuracy90.mean(), Model_Amplitude_Test_Accuracy90.std()
Model_Amplitude_Test_Accuracy80_mean, Model_Amplitude_Test_Accuracy80_std = Model_Amplitude_Test_Accruacy80.mean(), Model_Amplitude_Test_Accruacy80.std()

print("Model Amplitude")
print("------------------------")
print(f"Test Loss: {Model_Amplitude_Test_Loss_mean} ± {Model_Amplitude_Test_Loss_std}")
print(f"Test Accuracy90: {Model_Amplitude_Test_Accuracy90_mean} ± {Model_Amplitude_Test_Accuracy90_std}")
print(f"Test Accuracy80: {Model_Amplitude_Test_Accuracy80_mean} ± {Model_Amplitude_Test_Accuracy80_std}\n")
# Out:
# Model Amplitude
# ------------------------
# Test Loss: 0.030255882069468498 ± 0.0004369742424886393
# Test Accuracy90: 66.976 ± 2.463725634075355
# Test Accuracy80: 86.572 ± 1.0041792668642406
